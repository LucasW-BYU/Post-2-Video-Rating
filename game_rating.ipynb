# %%
import requests
import pandas as pd
import time

CLIENT_ID = '27m2cp7hi3y212prw0bpnsgi02lg3b'
CLIENT_SECRET = 'o42yuztwrcgiuiyzh638nc6mrfbyxr'

auth_url = 'https://id.twitch.tv/oauth2/token'
auth_params = {
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'grant_type': 'client_credentials'
}

auth_response = requests.post(auth_url, data=auth_params)
auth_data = auth_response.json()
access_token = auth_data['access_token']

url = "https://api.igdb.com/v4/games"
headers = {
    'Client-ID': CLIENT_ID,
    'Authorization': f'Bearer {access_token}'
}

fields = '''
fields name, genres.name, rating, platforms.name, first_release_date, involved_companies.company.name;
where rating != null & genres != null & platforms != null & first_release_date != null & involved_companies != null;
'''

all_games_data = []
limit = 100
offset = 0
total_games = 0


while total_games < 10000:
    body = f'''
    {fields}
    limit {limit};
    offset {offset};
    '''

    response = requests.post(url, headers=headers, data=body)
    games_data = response.json()

    complete_games = [
        game for game in games_data
        if 'rating' in game and 'genres' in game and 'platforms' in game
        and 'first_release_date' in game and 'involved_companies' in game
    ]


    all_games_data.extend(complete_games)
    total_games += len(complete_games)

    print(f"Retrieved {total_games} complete games so far...")

    if len(games_data) < limit:
        break

    offset += limit
    time.sleep(0.3)

games_df = pd.DataFrame(all_games_data)

def extract_info(column, subfield):
    return ', '.join([item[subfield] for item in column]) if isinstance(column, list) else 'Unknown'

def extract_companies(companies):
    return ', '.join([item['company']['name'] for item in companies]) if isinstance(companies, list) else 'Unknown'

games_df['genres'] = games_df['genres'].apply(lambda x: extract_info(x, 'name'))
games_df['platforms'] = games_df['platforms'].apply(lambda x: extract_info(x, 'name'))
games_df['companies'] = games_df['involved_companies'].apply(extract_companies)
games_df['release_date'] = pd.to_datetime(games_df['first_release_date'], unit='s', errors='coerce')
games_df.drop(columns=['involved_companies', 'first_release_date'], inplace=True)

games_df.to_csv('filtered_igdb_games_data.csv', index=False)

print(f"Total complete games retrieved: {total_games}")
print("Filtered Dataset:")
print(games_df)
# Out:
# Retrieved 100 complete games so far...
# Retrieved 200 complete games so far...
# Retrieved 300 complete games so far...
# Retrieved 400 complete games so far...
# Retrieved 500 complete games so far...
# Retrieved 600 complete games so far...
# Retrieved 700 complete games so far...
# Retrieved 800 complete games so far...
# Retrieved 900 complete games so far...
# Retrieved 1000 complete games so far...
# Retrieved 1100 complete games so far...
# Retrieved 1200 complete games so far...
# Retrieved 1300 complete games so far...
# Retrieved 1400 complete games so far...
# Retrieved 1500 complete games so far...
# Retrieved 1600 complete games so far...
# Retrieved 1700 complete games so far...
# Retrieved 1800 complete games so far...
# Retrieved 1900 complete games so far...
# Retrieved 2000 complete games so far...
# Retrieved 2100 complete games so far...
# Retrieved 2200 complete games so far...
# Retrieved 2300 complete games so far...
# Retrieved 2400 complete games so far...
# Retrieved 2500 complete games so far...
# Retrieved 2600 complete games so far...
# Retrieved 2700 complete games so far...
# Retrieved 2800 complete games so far...
# Retrieved 2900 complete games so far...
# Retrieved 3000 complete games so far...
# Retrieved 3100 complete games so far...
# Retrieved 3200 complete games so far...
# Retrieved 3300 complete games so far...
# Retrieved 3400 complete games so far...
# Retrieved 3500 complete games so far...
# Retrieved 3600 complete games so far...
# Retrieved 3700 complete games so far...
# Retrieved 3800 complete games so far...
# Retrieved 3900 complete games so far...
# Retrieved 4000 complete games so far...
# Retrieved 4100 complete games so far...
# Retrieved 4200 complete games so far...
# Retrieved 4300 complete games so far...
# Retrieved 4400 complete games so far...
# Retrieved 4500 complete games so far...
# Retrieved 4600 complete games so far...
# Retrieved 4700 complete games so far...
# Retrieved 4800 complete games so far...
# Retrieved 4900 complete games so far...
# Retrieved 5000 complete games so far...
# Retrieved 5100 complete games so far...
# Retrieved 5200 complete games so far...
# Retrieved 5300 complete games so far...
# Retrieved 5400 complete games so far...
# Retrieved 5500 complete games so far...
# Retrieved 5600 complete games so far...
# Retrieved 5700 complete games so far...
# Retrieved 5800 complete games so far...
# Retrieved 5900 complete games so far...
# Retrieved 6000 complete games so far...
# Retrieved 6100 complete games so far...
# Retrieved 6200 complete games so far...
# Retrieved 6300 complete games so far...
# Retrieved 6400 complete games so far...
# Retrieved 6500 complete games so far...
# Retrieved 6600 complete games so far...
# Retrieved 6700 complete games so far...
# Retrieved 6800 complete games so far...
# Retrieved 6900 complete games so far...
# Retrieved 7000 complete games so far...
# Retrieved 7100 complete games so far...
# Retrieved 7200 complete games so far...
# Retrieved 7300 complete games so far...
# Retrieved 7400 complete games so far...
# Retrieved 7500 complete games so far...
# Retrieved 7600 complete games so far...
# Retrieved 7700 complete games so far...
# Retrieved 7800 complete games so far...
# Retrieved 7900 complete games so far...
# Retrieved 8000 complete games so far...
# Retrieved 8100 complete games so far...
# Retrieved 8200 complete games so far...
# Retrieved 8300 complete games so far...
# Retrieved 8400 complete games so far...
# Retrieved 8500 complete games so far...
# Retrieved 8600 complete games so far...
# Retrieved 8700 complete games so far...
# Retrieved 8800 complete games so far...
# Retrieved 8900 complete games so far...
# Retrieved 9000 complete games so far...
# Retrieved 9100 complete games so far...
# Retrieved 9200 complete games so far...
# Retrieved 9300 complete games so far...
# Retrieved 9400 complete games so far...
# Retrieved 9500 complete games so far...
# Retrieved 9600 complete games so far...
# Retrieved 9700 complete games so far...
# Retrieved 9800 complete games so far...
# Retrieved 9900 complete games so far...
# Retrieved 10000 complete games so far...
# Total complete games retrieved: 10000
# Filtered Dataset:
#           id                                             genres  \
# 0       5668                                            Shooter
# 1     118128     Role-playing (RPG), Strategy, Adventure, Indie
# 2       6668                                  Puzzle, Adventure
# 3      83466  Puzzle, Strategy, Turn-based strategy (TBS), A...
# 4        394  Role-playing (RPG), Simulator, Strategy, Turn-...
# ...      ...                                                ...
# 9995   17052                 Point-and-click, Puzzle, Adventure
# 9996   75100               Role-playing (RPG), Adventure, Indie
# 9997   31819                                              Indie
# 9998    9130                       Puzzle, Simulator, Adventure
# 9999    8254                                 Shooter, Adventure
#
#                                              name  \
# 0                                        Commando
# 1                          Little Dungeon Stories
# 2                               Escape the Museum
# 3                                Spider Solitaire
# 4     Final Fantasy Tactics: The War of the Lions
# ...                                           ...
# 9995                  Return to Mysterious Island
# 9996                        Heroes of Hammerwatch
# 9997                                      The Hex
# 9998                                       Seaman
# 9999                                Resident Evil
#
#                                               platforms     rating  \
# 0     Wii, DOS, Commodore C64/128/MAX, Amiga, Amstra...  71.753318
# 1                                PC (Microsoft Windows)  50.000000
# 2              Wii, PC (Microsoft Windows), Nintendo DS  50.000000
# 3                                       Nintendo Switch  70.000000
# 4                    Android, PlayStation Portable, iOS  89.002382
# ...                                                 ...        ...
# 9995                             PC (Microsoft Windows)  70.287759
# 9996                      Linux, PC (Microsoft Windows)  69.994023
# 9997                 Linux, PC (Microsoft Windows), Mac  81.136882
# 9998   PC (Microsoft Windows), PlayStation 2, Dreamcast  79.931056
# 9999  PC (Microsoft Windows), PlayStation 3, Xbox 36...  85.747154
#
#                                               companies release_date
# 0     Data East USA, INTV Corporation, Atari Corpora...   1985-04-02
# 1                David Moralejo Sánchez, Grab The Games   2019-12-06
# 2     Majesco Entertainment, Gogii Games, GameMill E...   2009-04-01
# 3                                         Baltoro Games   2020-01-16
# 4     Square Enix, Tose, Square Enix Product Develop...   2007-05-08
# ...                                                 ...          ...
# 9995                    Anuman, Microids, Kheops Studio   2004-11-19
# 9996                                         Crackshell   2018-03-01
# 9997                               Daniel Mullins Games   2018-10-16
# 9998                        Sega, Jellyvision, Vivarium   1999-07-29
# 9999                                Capcom, K2 Co. Ltd.   2014-11-27
#
# [10000 rows x 7 columns]

# %%
# Sort the DataFrame by the 'rating' column in descending order
games_df = games_df.sort_values(by='rating', ascending=False)

# Save to CSV for future analysis
games_df.to_csv('filtered_igdb_games_data_sorted.csv', index=False)

print("Games sorted by rating (high to low):")
print(games_df)
# Out:
# Games sorted by rating (high to low):
#           id                                             genres  \
# 8527   15188                                Simulator, Strategy
# 5252  264773                  Hack and slash/Beat 'em up, Indie
# 6194   46147                                 Role-playing (RPG)
# 5632    5010                                   Simulator, Sport
# 68     88973            Platform, Role-playing (RPG), Adventure
# ...      ...                                                ...
# 1800   87776                          Role-playing (RPG), Indie
# 5491   13457  Role-playing (RPG), Strategy, Turn-based strat...
# 9374    9077                                             Arcade
# 3650  142217                                   Adventure, Indie
# 1857  144040                      Role-playing (RPG), Adventure
#
#                                                    name  \
# 8527                                 Imperium Galactica
# 5252                                   Lizards Must Die
# 6194                                 Golden Axe Warrior
# 5632                                MLB Power Pros 2008
# 68                                         Goblin Sword
# ...                                                 ...
# 1800                                    Dead Frontier 2
# 5491  Might & Magic: Heroes VI - Pirates of the Sava...
# 9374                                           CrazyBus
# 3650                                           Sunlight
# 1857                     Final Fantasy VII: Ever Crisis
#
#                                  platforms     rating  \
# 8527      PC (Microsoft Windows), DOS, iOS  99.894954
# 5252                PC (Microsoft Windows)  99.778951
# 6194           Sega Master System/Mark III  99.537230
# 5632       Wii, PlayStation 2, Nintendo DS  99.530611
# 68                    iOS, Nintendo Switch  99.468662
# ...                                    ...        ...
# 1800                PC (Microsoft Windows)  11.666392
# 5491                PC (Microsoft Windows)  11.493802
# 9374               Sega Mega Drive/Genesis  11.356651
# 3650                PC (Microsoft Windows)  10.795451
# 1857  PC (Microsoft Windows), Android, iOS  10.421314
#
#                                               companies release_date
# 8527           Digital Reality, GT Interactive Software   1997-03-01
# 5252          Agafonoff, The Bratans, Smola Game Studio   2023-09-27
# 6194                    Tec Toy, Sega Enterprises, Ltd.   1991-07-01
# 5632                                  2K Sports, Konami   2008-07-29
# 68                                         Gelato Games   2014-09-11
# ...                                                 ...          ...
# 1800                                      Creaky Corpse   2019-07-15
# 5491  Black Hole Entertainment, Limbic Entertainment...   2012-07-12
# 9374                   Devster Specialties, Tom Scripts   2004-12-31
# 3650                                   Krillbite Studio   2021-01-14
# 1857  Applibot, Inc, Square Enix, Square Enix Creati...   2023-09-07
#
# [10000 rows x 7 columns]
